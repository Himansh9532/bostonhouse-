# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("BostonHousing.csv")

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#Missing Value
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
#EDA 
corr = df.corr()

# %%
corr
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
df = df.rename(columns = {"medv":"Price"})

# %%
corr = df.corr()

# %%
corr
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(corr)

# %%
plt.scatter(df["crim"] , df["Price"])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
import seaborn as sns
sns.regplot(x = "rm" , y = "Price" , data = df )
# Out:
# <Axes: xlabel='rm', ylabel='Price'>

# %%
sns.regplot(x = "chas" , y = "Price" , data = df )
# Out:
# <Axes: xlabel='chas', ylabel='Price'>

# %%
sns.regplot(x = "age" , y = "Price" , data = df )
# Out:
# <Axes: xlabel='age', ylabel='Price'>

# %%
x = df.drop("Price" , axis = 1)
y = df["Price"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test =  train_test_split(x,y , test_size = 0.30 , random_state = 42)

# %%
x_train.shape, y_train.shape , x_test.shape , y_test.shape
# Out:
# ((354, 13), (354,), (152, 13), (152,))

# %%
#STANDARDIZE THE DA
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[-0.41425879, -0.50512499, -1.29214218, ...,  0.18727079,
#          0.39651419, -1.01531611],
#        [-0.40200818, -0.50512499, -0.16208345, ..., -0.21208981,
#          0.3870674 , -0.05366252],
#        [-0.39721053, -0.50512499, -0.60948856, ..., -0.16771641,
#          0.42854113, -0.31132373],
#        ...,
#        [-0.41604586,  3.03838247, -1.3166773 , ..., -0.56707702,
#          0.35987906, -0.90549329],
#        [ 0.92611293, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.87841346,  1.52750437],
#        [-0.39030549, -0.50512499, -0.37135358, ...,  1.16348561,
#         -3.32828832, -0.25218837]])

# %%
x_test
# Out:
# array([[-0.406801  , -0.50512499, -1.02225586, ..., -0.74457062,
#          0.41241246, -0.47605794],
#        [-0.41105674,  1.26662874, -0.68165068, ..., -0.30083661,
#          0.42854113, -1.25185755],
#        [-0.4051199 , -0.50512499,  2.39678516, ...,  0.8084984 ,
#          0.35031705,  0.79535229],
#        ...,
#        [-0.35439903, -0.50512499, -0.71195877, ..., -0.38958342,
#          0.25688594, -1.09697922],
#        [ 0.25423453, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.98970133,  0.53487511],
#        [ 0.77732457, -0.50512499,  1.00549958, ...,  0.8528718 ,
#          0.33199949,  0.56585078]])

# %% [markdown]
# # Model Trainning

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-1.10834602,  0.80843998,  0.34313466,  0.81386426, -1.79804295,
#         2.913858  , -0.29893918, -2.94251148,  2.09419303, -1.44706731,
#        -2.05232232,  1.02375187, -3.88579002])

# %%
lr.intercept_
# Out:
# 23.01581920903955

# %%
lr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
#prediction data
reg_pred = lr.predict(x_test)

# %%
reg_pred
# Out:
# array([28.64896005, 36.49501384, 15.4111932 , 25.40321303, 18.85527988,
#        23.14668944, 17.3921241 , 14.07859899, 23.03692679, 20.59943345,
#        24.82286159, 18.53057049, -6.86543527, 21.80172334, 19.22571177,
#        26.19191985, 20.27733882,  5.61596432, 40.44887974, 17.57695918,
#        27.44319095, 30.1715964 , 10.94055823, 24.02083139, 18.07693812,
#        15.934748  , 23.12614028, 14.56052142, 22.33482544, 19.3257627 ,
#        22.16564973, 25.19476081, 25.31372473, 18.51345025, 16.6223286 ,
#        17.50268505, 30.94992991, 20.19201752, 23.90440431, 24.86975466,
#        13.93767876, 31.82504715, 42.56978796, 17.62323805, 27.01963242,
#        17.19006621, 13.80594006, 26.10356557, 20.31516118, 30.08649576,
#        21.3124053 , 34.15739602, 15.60444981, 26.11247588, 39.31613646,
#        22.99282065, 18.95764781, 33.05555669, 24.85114223, 12.91729352,
#        22.68101452, 30.80336295, 31.63522027, 16.29833689, 21.07379993,
# ...

# %%
#plot scatter plot for predition
plt.scatter(reg_pred,y_test)
plt.xlabel("Predicted")
plt.ylabel("test")
# Out:
# Text(0, 0.5, 'test')

# %%
residuals = y_test - reg_pred

# %%
residuals
# Out:
# 173    -5.048960
# 274    -4.095014
# 491    -1.811193
# 72     -2.603213
# 452    -2.755280
#          ...
# 441    -0.303672
# 23      1.114059
# 225    10.016575
# 433    -2.382863
# 447    -5.685618
# Name: Price, Length: 152, dtype: float64

# %%
# plot this residual error
sns.displot(residuals , kind = "kde")

# %%
#scatterplot and prediction
plt.scatter(reg_pred , residuals)

# %%
mae = mean_absolute_error(y_test, reg_pred)
mse = mean_squared_error(y_test, reg_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, reg_pred)
mae, mse, rmse, r2
# Out:
# (3.1627098714574045,
#  21.517444231177205,
#  4.6386899261728205,
#  0.7112260057484933)

# %% [markdown]
# # R SQUARE AND ADJUSTED R SQUARE

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test , reg_pred)

# %%
score
# Out:
# 0.7112260057484933

# %% [markdown]
# # display adjusted RSQUARED

# %%
from sklearn.metrics import r2_score

# %%
# Let's check the scaler's mean and standard deviation used during the transformation
scaler_mean = scaler.mean_
scaler_scale = scaler.scale_

# Checking if these values were consistently applied to both training and test sets
x_train_scaled_check = (x_train - scaler_mean) / scaler_scale
x_test_scaled_check = (x_test - scaler_mean) / scaler_scale

# Comparing these manual scalings with the already scaled versions
np.allclose(x_train, x_train_scaled_check), np.allclose(x_test, x_test_scaled_check)
# Out:
# (False, False)

# %%
score = r2_score(y_test , reg_pred)
print(score)
# Out:
# 0.7112260057484933

# %% [markdown]
# # <!-- Pickling The Model File For Deployment
#  -->

# %%
# Pickling The Model File For Deployment

# %%
# Pickle the model for deployment
import pickle
model_filename = 'linear_regression_model.pkl'
with open(model_filename, 'wb') as file:
    pickle.dump(lr, file)

# %%
# Pickle the scaler as well (to ensure future data is scaled the same way)
scaler_filename = 'scaler.pkl'
with open(scaler_filename, 'wb') as file:
    pickle.dump(scaler, file)

print("Model and scaler have been pickled!")
# Out:
# Model and scaler have been pickled!

# %%
 #Loading the pickled model
with open('linear_regression_model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# Loading the pickled scaler
with open('scaler.pkl', 'rb') as file:
    loaded_scaler = pickle.load(file)

# %%
# Check the scaler's mean and standard deviation used during the transformation
scaler_mean = scaler.mean_
scaler_scale = scaler.scale_

# Print the scaler's mean and scale for verification
print("Scaler Mean:", scaler_mean)
print("Scaler Scale:", scaler_scale)

# Manually scale the original datasets
x_train_original = pd.DataFrame(scaler.inverse_transform(x_train), columns=x.columns)  # Inverse transform to get original values
x_test_original = pd.DataFrame(scaler.inverse_transform(x_test), columns=x.columns)

# Manually scaling the original data
x_train_scaled_check = (x_train_original - scaler_mean) / scaler_scale
x_test_scaled_check = (x_test_original - scaler_mean) / scaler_scale

# Comparing the already scaled versions with manually scaled ones
train_scaling_correct = np.allclose(x_train, x_train_scaled_check)
test_scaling_correct = np.allclose(x_test, x_test_scaled_check)

# Output the results and the first few rows for inspection
print("Training Scaling Correct:", train_scaling_correct)
print("Testing Scaling Correct:", test_scaling_correct)

# Display the first few rows of both manually and automatically scaled data
print("\nManually Scaled Training Data:\n", x_train_scaled_check[:5])
print("\nAutomatically Scaled Training Data:\n", x_train[:5])

print("\nManually Scaled Testing Data:\n", x_test_scaled_check[:5])
print("\nAutomatically Scaled Testing Data:\n", x_test[:5])
# Out:
# Scaler Mean: [3.46988686e+00 1.14039548e+01 1.11330508e+01 7.34463277e-02
#  5.57259322e-01 6.32567232e+00 6.87997175e+01 3.76587401e+00
#  9.43785311e+00 4.07042373e+02 1.82779661e+01 3.59701808e+02
#  1.24211299e+01]
# Scaler Scale: [8.30407703e+00 2.25765011e+01 6.92884344e+00 2.60867715e-01
#  1.16626831e-01 7.18194456e-01 2.76262572e+01 2.12302684e+00
#  8.62775916e+00 1.66286870e+02 2.25360235e+00 8.68019175e+01
#  7.10234960e+00]
# Training Scaling Correct: True
# Testing Scaling Correct: True
#
# Manually Scaled Training Data:
#         crim        zn     indus      chas       nox        rm       age  \
# 0 -0.414259 -0.505125 -1.292142 -0.281546 -0.851085  0.145264 -0.365584
# 1 -0.402008 -0.505125 -0.162083 -0.281546 -0.087967 -0.208401  0.133941
# 2 -0.397211 -0.505125 -0.609489 -0.281546 -0.936828 -0.896237 -1.266900
# 3 -0.290936 -0.505125 -0.431970 -0.281546 -0.165136 -0.543965 -1.429789
# 4  1.457816 -0.505125  1.005500 -0.281546  0.194987 -0.556496  0.079645
#
# ...
